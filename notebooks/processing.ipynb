# %%
import pandas as pd
from pathlib import Path

# %%
ROOT = Path.cwd().parent
path_raw = ROOT / "data" / "raw" / "heart.csv"
df = pd.read_csv(path_raw)
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# ### In the previous section , we saw that there is no null values ; but we observed that theres a problema with the column name "Cholesterol", theres a lot of patients with 0 .

# %%
df["Cholesterol"].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %%
df[df["Cholesterol"]==0].shape
# Out:
# (172, 12)

# %%
df_clean= df[df["Cholesterol"]!=0]
print("original shape:", df.shape)
print("cleaned shape:", df_clean.shape)
# Out:
# original shape: (918, 12)
# cleaned shape: (746, 12)

# %%
df["HeartDisease"].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64
